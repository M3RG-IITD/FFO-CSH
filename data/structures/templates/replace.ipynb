# %%
import os

def process_files(base_inputdir, base_outputdir, folder_file_replacement_map):
    for folder, data in folder_file_replacement_map.items():
        files = data['files']
        replacements = data['replacements']

        input_folder_path = os.path.join(base_inputdir, folder)
        output_folder_path = os.path.join(base_outputdir, folder)
        os.makedirs(output_folder_path, exist_ok=True)

        for file in files:
            input_file_path = os.path.join(input_folder_path, file)
            output_file_path = os.path.join(output_folder_path, file)

            with open(input_file_path, 'r') as infile, open(output_file_path, 'w') as outfile:
                for line in infile:
                    for old_text, new_text in replacements.items():
                        if old_text in line:
                            line = line.replace(old_text, new_text)
                    outfile.write(line)

            print(f"Processed {input_file_path} --> {output_file_path}")
    print("All replacements done across folders.")

# Base directories
base_inputdir = '../../data/structures/templates/template_car_mdf/'
base_outputdir = '../../data/structures/templates/template_car_mdf/replaced/'

# Folder-wise files and their specific replacements
folder_file_replacement_map = {
    'Tob11_car_mdf': {
        'files': ['Tob11_004_Bulk_cV05_r00.car', 'Tob11_004_vacuum_cV05_r01.car', 'Tob11_100_Bulk_cV05_r00.car', 'Tob11_100_vacuum_cV05_r00.car', 'tob11_221.car'],
        'replacements': {
            'sc2     Si  1.000': 'sc2     Si  {q_sc2_3}',
            'sc3     Si  1.000': 'sc3     Si  {q_sc2_3}',
            'oc12    O  -0.560': 'oc12    O   {q_oc12}',
            'oc13    O  -0.940': 'oc13    O   {q_oc13}',
            'ocx     O  -0.580': 'ocx     O   {q_ocx}',
            'ca+t    Ca  1.500': 'ca+t    Ca  {q_cat}',
            'oc14    O  -0.670': 'oc14    O   {q_oc14}',
            'hoy     H   0.400': 'hoy     H   {q_hoy}',
        }
    },
    'Tob11H_car_mdf': {
        'files': ['Tob11_Hamid_002_Cleaved_cV02_r00.car', 'Tob11_Hamid_004_002_Bulk_cV02_r00.car', 'Tob11_Hamid_004_Cleaved_cV02_r00.car', 'Tob11_Hamid_100_Bulk_cV02_r00.car', 'Tob11_Hamid_100_Cleaved_cV02_r00.car', 'tob11H_221.car'],
        'replacements': {            
            'oc13    O  -0.940': 'oc13    O   {q_oc13}',
            'ca+t    Ca  1.500': 'ca+t    Ca  {q_cat}',
            'oc14    O  -0.670': 'oc14    O   {q_oc14}',
            'oc12    O  -0.580': 'oc12    O   {q_oc12}',
            'casl    Ca  1.700': 'casl    Ca  {q_casl}',
            'oc22    O  -1.040': 'oc22    O   {q_oc22}',
            'sc2     Si  1.000': 'sc2     Si  {q_sc2_3}',
            'sc3     Si  1.000': 'sc3     Si  {q_sc2_3}',
            'hoy     H   0.400': 'hoy     H   {q_hoy}',
        }
    },
    'Tob14_car_mdf': {
        'files': ['Tob14_001_004_Bulk_cV07_r01.car', 'Tob14_001_vacuum_cV07_r01.car', 'Tob14_004_vacuum_cV07_r01.car', 'Tob14_100_Bulk_cV07_r01.car', 'Tob14_100_vacuum_cV07_r01.car', 'tob14_221.car'],
        'replacements': {
            'oc22    O  -1.080': 'oc22    O   {q_oc22}',
            'ca+t    Ca  1.500': 'ca+t    Ca  {q_cat}',
            'sc2     Si  1.000': 'sc2     Si  {q_sc2_3}',
            'sc3     Si  1.000': 'sc3     Si  {q_sc2_3}',
            'oc12    O  -0.580': 'oc12    O   {q_oc12}',
            'oc13    O  -0.940': 'oc13    O   {q_oc13}',
            'oc14    O  -0.670': 'oc14    O   {q_oc14}',
            'hoy     H   0.400': 'hoy     H   {q_hoy}',
            'casl    Ca  1.700': 'casl    O   {q_casl}',
        }
    }
}

# Run the processing
process_files(base_inputdir, base_outputdir, folder_file_replacement_map)

# %%
import os

def process_mdf_files(base_inputdir, base_outputdir, folder_file_replacement_map):
    for folder, data in folder_file_replacement_map.items():
        files = data['files']
        replacements = data['replacements']

        input_folder_path = os.path.join(base_inputdir, folder)
        output_folder_path = os.path.join(base_outputdir, folder)
        os.makedirs(output_folder_path, exist_ok=True)

        for file in files:
            input_file_path = os.path.join(input_folder_path, file)
            output_file_path = os.path.join(output_folder_path, file)

            with open(input_file_path, 'r') as infile, open(output_file_path, 'w') as outfile:
                for line in infile:
                    for old_text, new_text in replacements.items():
                        if old_text in line:
                            line = line.replace(old_text, new_text)
                    outfile.write(line)

            print(f"Processed {input_file_path} --> {output_file_path}")
    print("All replacements done across folders.")

# Base directories
base_inputdir = '../../data/structures/templates/template_car_mdf/'
base_outputdir = '../../data/structures/templates/template_car_mdf/replaced/'

# Folder-wise files and their specific replacements for MDF files
folder_file_replacement_map = {
    'Tob11_car_mdf': {
        'files': ['Tob11_004_Bulk_cV05_r00.mdf', 'Tob11_004_vacuum_cV05_r01.mdf', 'Tob11_100_Bulk_cV05_r00.mdf', 'Tob11_100_vacuum_cV05_r00.mdf', 'tob11_221.mdf'],
        'replacements': {
            'sc2     ?     0  0     1.000': 'sc2     ?     0  0     {q_sc2_3}',
            'sc3     ?     0  0     1.000': 'sc3     ?     0  0     {q_sc2_3}',
            'oc12    ?     0  0    -0.560': 'oc12    ?     0  0     {q_oc12}',
            'oc13    ?     0  1-   -0.940': 'oc13    ?     0  1-    {q_oc13}',
            'ocx     ?     0  0    -0.580': 'ocx     ?     0  0     {q_ocx}',
            'ca+t    ?     0  2+    1.500': 'ca+t    ?     0  2+    {q_cat}',
            'oc14    ?     0  0    -0.670': 'oc14    ?     0  0     {q_oc14}',
            'hoy     ?     0  0     0.400': 'hoy     ?     0  0     {q_hoy}',
        }
    },
    'Tob11H_car_mdf': {
        'files': ['Tob11_Hamid_002_Cleaved_cV02_r00.mdf', 'Tob11_Hamid_004_002_Bulk_cV02_r00.mdf', 'Tob11_Hamid_004_Cleaved_cV02_r00.mdf', 'Tob11_Hamid_100_Bulk_cV02_r00.mdf', 'Tob11_Hamid_100_Cleaved_cV02_r00.mdf', 'tob11H_221.mdf'],
        'replacements': {            
            'oc13    ?     0  1-   -0.940': 'oc13    ?     0  1-    {q_oc13}',
            'ca+t    ?     0  2+    1.500': 'ca+t    ?     0  2+    {q_cat}',
            'oc14    ?     0  0    -0.670': 'oc14    ?     0  0     {q_oc14}',
            'oc12    ?     0  0    -0.580': 'oc12    ?     0  0     {q_oc12}',
            'casl    ?     0  2+    1.700': 'casl    ?     0  2+    {q_casl}',
            'oc22    ?     0  1-   -1.040': 'oc22    ?     0  1-    {q_oc22}',
            'sc2     ?     0  0     1.000': 'sc2     ?     0  0     {q_sc2_3}',
            'sc3     ?     0  0     1.000': 'sc3     ?     0  0     {q_sc2_3}',
            'hoy     ?     0  0     0.400': 'hoy     ?     0  0     {q_hoy}',
        }
    },
    'Tob14_car_mdf': {
        'files': ['Tob14_001_004_Bulk_cV07_r01.mdf', 'Tob14_001_vacuum_cV07_r01.mdf', 'Tob14_004_vacuum_cV07_r01.mdf', 'Tob14_100_Bulk_cV07_r01.mdf', 'Tob14_100_vacuum_cV07_r01.mdf', 'tob14_221.mdf'],
        'replacements': {
            'oc22    ?     0  1-   -1.080': 'oc22    ?     0  1-    {q_oc22}',
            'ca+t    ?     0  2+    1.500': 'ca+t    ?     0  2+    {q_cat}',
            'sc2     ?     0  0     1.000': 'sc2     ?     0  0     {q_sc2_3}',
            'sc3     ?     0  0     1.000': 'sc3     ?     0  0     {q_sc2_3}',
            'oc12    ?     0  0    -0.580': 'oc12    ?     0  0     {q_oc12}',
            'oc13    ?     0  1-   -0.940': 'oc13    ?     0  1-    {q_oc13}',
            'oc14    ?     0  0    -0.670': 'oc14    ?     0  0     {q_oc14}',
            'hoy     ?     0  0     0.400': 'hoy     ?     0  0     {q_hoy}',
            'casl    ?     0  2+    1.700': 'casl    ?     0  2+    {q_casl}',
        }
    }
}
# Run the processing
process_mdf_files(base_inputdir, base_outputdir, folder_file_replacement_map)
